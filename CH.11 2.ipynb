# %% [markdown]
# # Chapter 11 Coding Set
# ## Masone T Yang
# ### Programming Exercises
# ### 1. Employee and ProductionWorker Classes
# Write an Employee class that keeps data attributes for the following pieces of information:
# • Employee name
# • Employee number
# Next, write a class named ProductionWorker that is a subclass of the Employee class.
# The ProductionWorker class should keep data attributes for the following information:
# • Shift number (an integer, such as 1, 2, or 3)
# • Hourly pay rate
# The workday is divided into two shifts: day and night. The shift attribute will hold an
# integer value representing the shift that the employee works. The day shift is shift 1 and the
# night shift is shift 2. Write the appropriate accessor and mutator methods for each class.
# Once you have written the classes, write a program that creates an object of the
# ProductionWorker class and prompts the user to enter data for each of the object’s data
# attributes. Store the data in the object, then use the object’s accessor methods to retrieve it
# and display it on the screen.

# %%
#The question is asking us to create an employee class that keeps data attributes for the  Employee name • Employee number.
#Then it asks to make a subclasss of the employee class.
#The subclass is keeping track of the hourly rate, shift number, and the two shifts. 
#Finally, you print out all of the code to display the data attriubutes for the names, numbers, shifts, and hourly rates. 


class Employee:
    def __init__(self, name, emp_number):  # Constructor method for the Employee class
        self.name = name  # Assign the name parameter to the name attribute of the object
        self.emp_number = emp_number  # Assign the emp_number parameter to the emp_number attribute of the object
        
    def get_name(self):  # Method to retrieve the name attribute of the object
        return self.name
    
    def get_emp_number(self):  # Method to retrieve the emp_number attribute of the object
        return self.emp_number
    
    def set_emp_number(self, emp_number):  # Method to set the emp_number attribute of the object
        self.emp_number = emp_number


class ProductionWorker(Employee):  # Subclass ProductionWorker inheriting from Employee
    def __init__(self, name, emp_number, shift_number, hourly_pay_rate):  # Constructor method for ProductionWorker
        super().__init__(name, emp_number)  # Call the constructor of the parent class Employee
        self.shift_number = shift_number  # Assign the shift_number parameter to the shift_number attribute
        self.hourly_pay_rate = hourly_pay_rate  # Assign the hourly_pay_rate parameter to the hourly_pay_rate attribute
        
    def get_shift_number(self):  # Method to retrieve the shift_number attribute of the object
        return self.shift_number
    
    def get_hourly_pay_rate(self):  # Method to retrieve the hourly_pay_rate attribute of the object
        return self.hourly_pay_rate
    
    def set_hourly_pay_rate(self, hourly_pay_rate):  # Method to set the hourly_pay_rate attribute of the object
        self.hourly_pay_rate = hourly_pay_rate
        
def main():
    
    name = input("Enter employee name: ")  # Prompt the user to enter employee name
    emp_number = input("Enter employee number: ")  # Prompt the user to enter employee number
    shift_number = int(input("Enter shift number 1 for day, 2 for night: "))  # Prompt the user to enter shift number
    hourly_pay_rate = float(input("Enter hourly pay rate: "))  # Prompt the user to enter hourly pay rate
    
    worker = ProductionWorker(name, emp_number, shift_number, hourly_pay_rate)  # Create a ProductionWorker object
    
    print("\nEmployee Information:")  # Print a header for employee information
    print("Name:", worker.get_name())  # Print the employee name
    print("Employee Number:", worker.get_emp_number())  # Print the employee number
    if worker.get_shift_number() == 1:  # Check if the shift number is 1 (day shift)
        print("Shift: Day")  # Print that it's a day shift
    elif worker.get_shift_number() == 2:  # Check if the shift number is 2 (night shift)
        print("Shift: Night")  # Print that it's a night shift
    print("Hourly Pay Rate: $", worker.get_hourly_pay_rate())  # Print the hourly pay rate
    
if __name__ == "__main__":  # Check if the script is being run directly
    main()  # Call the main function
# Out:
# Enter employee name: Masone
# Enter employee number: 1
# Enter shift number 1 for day, 2 for night: 2
# Enter hourly pay rate: 11.50
#
# Employee Information:
# Name: Masone
# Employee Number: 1
# Shift: Night
# Hourly Pay Rate: $ 11.5

# %% [markdown]
# ### 2. ShiftSupervisor Class
# In a particular factory, a shift supervisor is a salaried employee who supervises a shift. In
# addition to a salary, the shift supervisor earns a yearly bonus when his or her shift meets
# production goals. Write a ShiftSupervisor class that is a subclass of the Employee class
# you created in Programming Exercise 1. The ShiftSupervisor class should keep a data
# attribute for the annual salary, and a data attribute for the annual production bonus that
# a shift supervisor has earned. Demonstrate the class by writing a program that uses a
# ShiftSupervisor object

# %%
#First, the question asks us to create a subclass to the Employee class we created. 
#After, we incorportae the dta attributes for the annual salary and the bonus that they earned. 
#The bonus is annual and I chose to give them 500$ working at 25$ an hour. Which was random.
#Finally I printed out all of the data at



class ShiftSupervisor(Employee):
    def __init__(self, name, emp_number, annual_salary, annual_bonus):
        super().__init__(name, emp_number)  # Call the constructor of the parent class Employee
        self.annual_salary = annual_salary  # Assign the annual_salary parameter to the annual_salary attribute
        self.annual_bonus = annual_bonus  # Assign the annual_bonus parameter to the annual_bonus attribute

    def get_annual_salary(self):  # Method to retrieve the annual_salary attribute
        return self.annual_salary

    def get_annual_bonus(self):  # Method to retrieve the annual_bonus attribute
        return self.annual_bonus

    def set_annual_salary(self, annual_salary):  # Method to set the annual_salary attribute
        self.annual_salary = annual_salary

    def set_annual_bonus(self, annual_bonus):  # Method to set the annual_bonus attribute
        self.annual_bonus = annual_bonus


def main():
    name = input("Enter shift supervisor's name: ")  # Prompt the user to enter the shift supervisor's name
    emp_number = input("Enter shift supervisor's employee number: ")  # Prompt the user to enter the shift supervisor's employee number
    annual_salary = float(input("Enter shift supervisor's annual salary: "))  # Prompt the user to enter the shift supervisor's annual salary
    annual_bonus = float(input("Enter shift supervisor's annual bonus: "))  # Prompt the user to enter the shift supervisor's annual bonus

    supervisor = ShiftSupervisor(name, emp_number, annual_salary, annual_bonus)  # Create a ShiftSupervisor object

    print("\nShift Supervisor Information:")  # Print a header for shift supervisor information
    print("Name:", supervisor.get_name())  # Print the shift supervisor's name
    print("Employee Number:", supervisor.get_emp_number())  # Print the shift supervisor's employee number
    print("Annual Salary: $", supervisor.get_annual_salary())  # Print the shift supervisor's annual salary
    print("Annual Bonus: $", supervisor.get_annual_bonus())  # Print the shift supervisor's annual bonus


if __name__ == "__main__":  # Check if the script is being run directly
    main()  # Call the main function
# Out:
# Enter shift supervisor's name: Mark
# Enter shift supervisor's employee number: 2
# Enter shift supervisor's annual salary: 25
# Enter shift supervisor's annual bonus: 500
#
# Shift Supervisor Information:
# Name: Mark
# Employee Number: 2
# Annual Salary: $ 25.0
# Annual Bonus: $ 500.0
